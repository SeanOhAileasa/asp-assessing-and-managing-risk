# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/asp-assessing-and-managing-risk/blob/main/README.md) >
#
# ## CompTIA CASP+
# ###### Topic: ``Assessing and Managing Risk``
# ***

# %% [markdown]
# Course material for the ``CompTIA CASP+`` certification.

# %% [markdown]
# Recognizing threats and managing risk are key to hardening an organization's security posture.
#
# Exploring how to apply risk management frameworks to assess and mitigate risk, as well as how to identify threat actors and physical risks.
#
# Exploring how to mitigate risks related to human resources and social engineering techniques.
#
# Examine how to work with qualitative and quantitative risk analysis.
#
# Lastly, examine insider threats, supply chain dependencies, and sources of threat intelligence.

# %% [markdown]
# > Objectives
#
# - recognize factors that influence conducting a risk assessment as part of risk management
#
#
# - recognize how to apply risk management frameworks
#
#
# - identify various types of threat actors
#
#
# - recognize physical risks
#
#
# - take steps to minimize HR risks
#
#
# - recognize how deception techniques are used by attackers
#
#
# - analyze e-mail messages to identify phishing attempts
#
#
# - perform a quantitative risk analysis
#
#
# - perform a qualitative risk analysis
#
#
# - correlate security solutions to security requirements
#
#
# - describe how IT security must apply to internal networks
#
#
# - determine how to reduce the risk related to third-party dependency chains
#
#
# - identify multiple sources of threat intelligence

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Risk Management](#A) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Risk Management Frameworks](#B) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Threat Actors](#C) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Physical Risks](#D) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Human Resources Risk Mitigation](#E) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Social Engineering](#F) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Viewing Phishing E-mails](#G) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Quantitative Risk Analysis](#H) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Qualitative Risk Analysis](#I) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Security Objectives and Security Controls](#J) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [The Insider Threat](#K) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Third-party Dependencies](#L) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Threat Intelligence](#M) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="A"></a>
# ***
# ### Risk Management
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="B"></a>
# ***
# ### Risk Management Frameworks
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="C"></a>
# ***
# ### Threat Actors
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="D"></a>
# ***
# ### Physical Risks
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="E"></a>
# ***
# ### Human Resources Risk Mitigation
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="F"></a>
# ***
# ### Social Engineering
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="G"></a>
# ***
# ### Viewing Phishing E-mails
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="H"></a>
# ***
# ### Quantitative Risk Analysis
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="I"></a>
# ***
# ### Qualitative Risk Analysis
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="J"></a>
# ***
# ### Security Objectives and Security Controls
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="K"></a>
# ***
# ### The Insider Threat
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="L"></a>
# ***
# ### Third-party Dependencies
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="M"></a>
# ***
# ### Threat Intelligence
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# skillsoft, "Assessing and Managing Risk," [skillsoft.com](https://web.archive.org/web/20221102151824/https://www.skillsoft.com/get-free-trial), n.d..

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
